# %%
import json
import requests
import io
import os
import urllib
from docx import Document
from docx.shared import Inches
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.enum.text import WD_BREAK
from docx.shared import Pt

get_headers = {
    'Authorization': 'Bearer '
    }

questions_url = 'https://api.airtable.com/v0/appl09q3uKHeKNUnq/Export_to_word?view=Grid%20view'
questions = requests.get(questions_url, headers=get_headers)
questions_data = questions.json()

no_questions = len(questions_data['records'])

document = Document('template.docx')
font = document.styles['Normal'].font
font.name = 'Arial'
font.size = Pt(12)

document._body.clear_content()

intro = document.add_paragraph()
intro.alignment = WD_ALIGN_PARAGRAPH.CENTER
intro_font = intro.add_run('PART I')
intro_font.bold = True

rule = document.add_paragraph()
rule.alignment = WD_ALIGN_PARAGRAPH.JUSTIFY
rule.add_run(f'For each question from 1 to {no_questions}, four options are given. One of them is the correct answer. Make your choice (1, 2, 3 or 4). Shade the correct oval (1, 2, 3 or 4) on the Optical Answer Sheet.                                                                (24 x 2 marks)')

divider = document.add_paragraph()
divider.alignment = WD_ALIGN_PARAGRAPH.DISTRIBUTE
divider.add_run('_' * 64)

for i in questions_data['records']:
    question = i['fields']['Question']
    
    if '<diagram>' in question:
        pictures = i['fields']['Attachments']
        picture_url = []
        for picture in pictures:
            picture_url.append(picture['url'])
        question_list = question.split('<diagram>')
        diagram_count = question.count('<diagram>')
        count = 0
        p = document.add_paragraph(style='List Number')
        for question_part in question_list:
            p_text = p.add_run(question_part)
            if diagram_count != count:
                io_url = io.BytesIO(urllib.request.urlopen(picture_url[count]).read())
                p_text.add_picture(io_url)
            count += 1
        bracket = document.add_paragraph()
        bracket.alignment = WD_ALIGN_PARAGRAPH.RIGHT
        run = bracket.add_run(f'(\t)')

        if question == questions_data['records'][no_questions - 1]['fields']['Question']:
            end = document.add_paragraph()
            end.alignment = WD_ALIGN_PARAGRAPH.CENTER
            end_para = end.add_run('END OF BOOKLET A')
            end_para.bold = True
            end_para.add_break(WD_BREAK.PAGE)
            end_end = end.add_run('BLANK PAGE')
            end_end.bold = True

        else:
#             run = p.add_run()
            run.add_break(WD_BREAK.PAGE)
            
    else:
        p = document.add_paragraph(question, style='List Number')
        run = p.add_run()
        run.add_break(WD_BREAK.PAGE)

document.save('test.docx')
os.system('start test.docx')
# Out:
# 0

# %%
questions_url = 'https://api.airtable.com/v0/appl09q3uKHeKNUnq/Export_to_word?view=Grid%20view'
questions = requests.get(questions_url, headers=get_headers)
questions_data = questions.json()
for i in questions_data['records']:
    picture = i['fields']['Attachments']
    for j in picture:
        print(j['url'])
# print(picture)
# Out:
# https://dl.airtable.com/.attachments/e64210edcec5dee56719e05078726bde/a4c998b1/26i.jpg
# https://dl.airtable.com/.attachments/9692d7d817af7443adf59190e63fe8f4/ca437938/26ii.jpg
# https://dl.airtable.com/.attachments/5a4c9dd7d7cb58bed34fa1a949a0a586/62a83fd6/43ii.jpg
# https://dl.airtable.com/.attachments/2f60758989d861e1c85c9fb5f74cb0db/dcebe72c/43i.jpg
# https://dl.airtable.com/.attachments/426fdd6cc8f3662d2c5a1467971abe02/90a95bbe/42i.jpg
# https://dl.airtable.com/.attachments/b61fc44500d0fe2ed7cc23c63807c68e/53219221/42ii.jpg
# https://dl.airtable.com/.attachments/97513c0381943963d4dd20e4c0787650/79fda2ee/42iii.jpg

# %%
document = Document('template.docx')
for style in document.styles:
    print("style.name == %s" % style.name)
# Out:
# style.name == Normal
# style.name == Heading 1
# style.name == Heading 2
# style.name == Heading 3
# style.name == Heading 4
# style.name == Heading 5
# style.name == Heading 6
# style.name == Heading 7
# style.name == Heading 8
# style.name == Heading 9
# style.name == Default Paragraph Font
# style.name == Normal Table
# style.name == No List
# style.name == Header
# style.name == Header Char
# style.name == Footer
# style.name == Footer Char
# style.name == No Spacing
# style.name == Heading 1 Char
# style.name == Heading 2 Char
# style.name == Heading 3 Char
# style.name == Title
# style.name == Title Char
# style.name == Subtitle
# style.name == Subtitle Char
# style.name == List Paragraph
# style.name == Body Text
# style.name == Body Text Char
# style.name == Body Text 2
# style.name == Body Text 2 Char
# style.name == Body Text 3
# style.name == Body Text 3 Char
# style.name == List
# style.name == List 2
# style.name == List 3
# style.name == List Bullet
# style.name == List Bullet 2
# style.name == List Bullet 3
# style.name == List Number
# style.name == List Number 2
# style.name == List Number 3
# style.name == List Continue
# style.name == List Continue 2
# style.name == List Continue 3
# style.name == macro
# style.name == Macro Text Char
# style.name == Quote
# style.name == Quote Char
# style.name == Heading 4 Char
# style.name == Heading 5 Char
# style.name == Heading 6 Char
# style.name == Heading 7 Char
# style.name == Heading 8 Char
# style.name == Heading 9 Char
# style.name == Caption
# style.name == Strong
# style.name == Emphasis
# style.name == Intense Quote
# style.name == Intense Quote Char
# style.name == Subtle Emphasis
# style.name == Intense Emphasis
# style.name == Subtle Reference
# style.name == Intense Reference
# style.name == Book Title
# style.name == TOC Heading
# style.name == Table Grid
# style.name == Light Shading
# style.name == Light Shading Accent 1
# style.name == Light Shading Accent 2
# style.name == Light Shading Accent 3
# style.name == Light Shading Accent 4
# style.name == Light Shading Accent 5
# style.name == Light Shading Accent 6
# style.name == Light List
# style.name == Light List Accent 1
# style.name == Light List Accent 2
# style.name == Light List Accent 3
# style.name == Light List Accent 4
# style.name == Light List Accent 5
# style.name == Light List Accent 6
# style.name == Light Grid
# style.name == Light Grid Accent 1
# style.name == Light Grid Accent 2
# style.name == Light Grid Accent 3
# style.name == Light Grid Accent 4
# style.name == Light Grid Accent 5
# style.name == Light Grid Accent 6
# style.name == Medium Shading 1
# style.name == Medium Shading 1 Accent 1
# style.name == Medium Shading 1 Accent 2
# style.name == Medium Shading 1 Accent 3
# style.name == Medium Shading 1 Accent 4
# style.name == Medium Shading 1 Accent 5
# style.name == Medium Shading 1 Accent 6
# style.name == Medium Shading 2
# style.name == Medium Shading 2 Accent 1
# style.name == Medium Shading 2 Accent 2
# style.name == Medium Shading 2 Accent 3
# style.name == Medium Shading 2 Accent 4
# style.name == Medium Shading 2 Accent 5
# style.name == Medium Shading 2 Accent 6
# style.name == Medium List 1
# style.name == Medium List 1 Accent 1
# style.name == Medium List 1 Accent 2
# style.name == Medium List 1 Accent 3
# style.name == Medium List 1 Accent 4
# style.name == Medium List 1 Accent 5
# style.name == Medium List 1 Accent 6
# style.name == Medium List 2
# style.name == Medium List 2 Accent 1
# style.name == Medium List 2 Accent 2
# style.name == Medium List 2 Accent 3
# style.name == Medium List 2 Accent 4
# style.name == Medium List 2 Accent 5
# style.name == Medium List 2 Accent 6
# style.name == Medium Grid 1
# style.name == Medium Grid 1 Accent 1
# style.name == Medium Grid 1 Accent 2
# style.name == Medium Grid 1 Accent 3
# style.name == Medium Grid 1 Accent 4
# style.name == Medium Grid 1 Accent 5
# style.name == Medium Grid 1 Accent 6
# style.name == Medium Grid 2
# style.name == Medium Grid 2 Accent 1
# style.name == Medium Grid 2 Accent 2
# style.name == Medium Grid 2 Accent 3
# style.name == Medium Grid 2 Accent 4
# style.name == Medium Grid 2 Accent 5
# style.name == Medium Grid 2 Accent 6
# style.name == Medium Grid 3
# style.name == Medium Grid 3 Accent 1
# style.name == Medium Grid 3 Accent 2
# style.name == Medium Grid 3 Accent 3
# style.name == Medium Grid 3 Accent 4
# style.name == Medium Grid 3 Accent 5
# style.name == Medium Grid 3 Accent 6
# style.name == Dark List
# style.name == Dark List Accent 1
# style.name == Dark List Accent 2
# style.name == Dark List Accent 3
# style.name == Dark List Accent 4
# style.name == Dark List Accent 5
# style.name == Dark List Accent 6
# style.name == Colorful Shading
# style.name == Colorful Shading Accent 1
# style.name == Colorful Shading Accent 2
# style.name == Colorful Shading Accent 3
# style.name == Colorful Shading Accent 4
# style.name == Colorful Shading Accent 5
# style.name == Colorful Shading Accent 6
# style.name == Colorful List
# style.name == Colorful List Accent 1
# style.name == Colorful List Accent 2
# style.name == Colorful List Accent 3
# style.name == Colorful List Accent 4
# style.name == Colorful List Accent 5
# style.name == Colorful List Accent 6
# style.name == Colorful Grid
# style.name == Colorful Grid Accent 1
# style.name == Colorful Grid Accent 2
# style.name == Colorful Grid Accent 3
# style.name == Colorful Grid Accent 4
# style.name == Colorful Grid Accent 5
# style.name == Colorful Grid Accent 6
